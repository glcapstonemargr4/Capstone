# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pydicom

# %%
import os
os.chdir('/content/drive/MyDrive/Capstone')

# %%
import pydicom as dicom
import matplotlib.pyplot as plt
import os
import cv2
import PIL # optional
import pandas as pd
import csv

folder_path = '/content/drive/MyDrive/Capstone/stage_2_train_images'
jpg_folder_path = '/train1'
#os.mkdir(outdir)

# make it True if you want in PNG format
PNG = False

#print(os.listdir(folder_path))
images_path = os.listdir(folder_path)
for n, image in enumerate(images_path):
    ds = dicom.dcmread(os.path.join(folder_path, image))
    pixel_array_numpy = ds.pixel_array
    if PNG == False:
        image = image.replace('.dcm', '.jpg')
        
    else:
        image = image.replace('.dcm', '.png')
    cv2.imwrite(os.path.join(jpg_folder_path, image), pixel_array_numpy)
    print(os.path.join(jpg_folder_path, image))
    if n % 50 == 0:
        print('{} image converted'.format(n))

# %%
import pydicom as dicom
import matplotlib.pyplot as plt
import os
import cv2
import PIL # optional
import pandas as pd
import csv

# %%
proj_path= '/content/drive/MyDrive/Capstone'

# %%
# !pip install git+https://github.com/pydicom/pydicom.git
# Out:
# ...
#   Cloning https://github.com/pydicom/pydicom.git to /tmp/pip-req-build-yiv9bffy
#   Running command git clone -q https://github.com/pydicom/pydicom.git /tmp/pip-req-build-yiv9bffy
# ...
#   Created wheel for pydicom: filename=pydicom-2.2.0.dev0-cp36-none-any.whl size=1888186 sha256=f0fc079b8c53f6c96093a647c6d8d5b79c8142f1c42f82f7d49bead74687da85
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1tsft4lk/wheels/da/32/3a/d6343243f5f7f2a1931f07d73081eaf420f2eb4b0f570781ca
# Successfully built pydicom
# ...
#   Found existing installation: pydicom 2.1.2
#     Uninstalling pydicom-2.1.2:
#       Successfully uninstalled pydicom-2.1.2
# ...

# %%
import pydicom

# %%
import cv2
import os

inputdir = proj_path + '/stage_2_test_images/'
outdir = proj_path + '/test_jpg/'
temp_list = [ f for f in  os.listdir(inputdir)]
for f in temp_list:   
    ds = pydicom.read_file(inputdir + f) 
    img = ds.pixel_array # get image array
    cv2.imwrite(outdir + f.replace('.dcm','.jpg'),img)

# %%
import os
os.chdir('/content/drive/MyDrive/Capstone')

# %%
# %ls
# Out:
# Dataset/                         stage_2_test_images/
# model-0.95.h5                    stage_2_test_images.zip
# model_frcnn_vgg.hdf5             stage_2_train_images/
# model_vgg_config.pickle          stage_2_train_images.zip
# new.txt                          stage_2_train_labels1.csv
# record.csv                       submission.csv
# RESNET50-FEB.hdf5                test_jpg/
# stage_2_detailed_class_info.csv  vgg16_weights_tf_dim_ordering_tf_kernels.h5
# stage_2_sample_submission.csv

# %% [markdown]
# preprocessing

# %%
ls
# Out:
# drive/  sample_data/
